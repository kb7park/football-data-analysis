# %%
import sqlite3
import pandas as pd

conn=sqlite3.connect("football.db")

players=pd.read_csv("player.csv")


players.to_sql(
    "players",
    conn,
    if_exists="replace",
    index=False
)
# Out:
# 5

# %%
query = """
SELECT * 
FROM players
LIMIT 5;
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists  team
# 0    손흥민     15        9   토트넘
# 1    이강인      8        6    파리
# 2    황희찬     10        3   울브즈
# 3    김민재      2        1    뮌헨
# 4    조규성      6        2  미트윌란

# %%
query = """
SELECT *
FROM players;
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists  team
# 0    손흥민     15        9   토트넘
# 1    이강인      8        6    파리
# 2    황희찬     10        3   울브즈
# 3    김민재      2        1    뮌헨
# 4    조규성      6        2  미트윌란

# %%
query = """
SELECT player, team
FROM players;
"""

pd.read_sql_query(query, conn)
# Out:
#   player  team
# 0    손흥민   토트넘
# 1    이강인    파리
# 2    황희찬   울브즈
# 3    김민재    뮌헨
# 4    조규성  미트윌란

# %%
query = """
SELECT DISTINCT goals
FROM players;
"""

pd.read_sql_query(query, conn)
# Out:
#    goals
# 0     15
# 1      8
# 2     10
# 3      2
# 4      6

# %%
query = """
SELECT DISTINCT assists
FROM players;
"""

pd.read_sql_query(query, conn)
# Out:
#    assists
# 0        9
# 1        6
# 2        3
# 3        1
# 4        2

# %%
query = """
SELECT *
FROM players;
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists  team
# 0    손흥민     15        9   토트넘
# 1    이강인      8        6    파리
# 2    황희찬     10        3   울브즈
# 3    김민재      2        1    뮌헨
# 4    조규성      6        2  미트윌란

# %%
query = """
SELECT *
FROM players
WHERE goals>=5;
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists  team
# 0    손흥민     15        9   토트넘
# 1    이강인      8        6    파리
# 2    황희찬     10        3   울브즈
# 3    조규성      6        2  미트윌란

# %%
query = """
SELECT *
FROM players
WHERE goals>=5
AND assists>=2;
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists  team
# 0    손흥민     15        9   토트넘
# 1    이강인      8        6    파리
# 2    황희찬     10        3   울브즈
# 3    조규성      6        2  미트윌란

# %%
query = """
SELECT *
FROM players
WHERE goals>=5
OR assists>=2;
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists  team
# 0    손흥민     15        9   토트넘
# 1    이강인      8        6    파리
# 2    황희찬     10        3   울브즈
# 3    조규성      6        2  미트윌란

# %%
#1
import sqlite3
import pandas as pd

conn=sqlite3.connect("football.db")

query = """
SELECT *
FROM players
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists  team
# 0    손흥민     15        9   토트넘
# 1    이강인      8        6    파리
# 2    황희찬     10        3   울브즈
# 3    김민재      2        1    뮌헨
# 4    조규성      6        2  미트윌란

# %%
#2
query = """
SELECT player
FROM players
"""

pd.read_sql_query(query, conn)
# Out:
#   player
# 0    손흥민
# 1    이강인
# 2    황희찬
# 3    김민재
# 4    조규성

# %%
#3
query = """
SELECT player, goals
FROM players
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals
# 0    손흥민     15
# 1    이강인      8
# 2    황희찬     10
# 3    김민재      2
# 4    조규성      6

# %%
#4
query = """
SELECT player, goals, assists
FROM players
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists
# 0    손흥민     15        9
# 1    이강인      8        6
# 2    황희찬     10        3
# 3    김민재      2        1
# 4    조규성      6        2

# %%
#5
query = """
SELECT player, team
FROM players
"""

pd.read_sql_query(query, conn)
# Out:
#   player  team
# 0    손흥민   토트넘
# 1    이강인    파리
# 2    황희찬   울브즈
# 3    김민재    뮌헨
# 4    조규성  미트윌란

# %%
#6
query = """
SELECT DISTINCT team
FROM players
"""

pd.read_sql_query(query, conn)
# Out:
#    team
# 0   토트넘
# 1    파리
# 2   울브즈
# 3    뮌헨
# 4  미트윌란

# %%
#7
query = """
SELECT DISTINCT goals
FROM players
"""

pd.read_sql_query(query, conn)
# Out:
#    goals
# 0     15
# 1      8
# 2     10
# 3      2
# 4      6

# %%
#8
query = """
SELECT DISTINCT assists
FROM players
"""

pd.read_sql_query(query, conn)
# Out:
#    assists
# 0        9
# 1        6
# 2        3
# 3        1
# 4        2

# %%
#9
query = """
SELECT DISTINCT team, goals
FROM players
"""

pd.read_sql_query(query, conn)
# Out:
#    team  goals
# 0   토트넘     15
# 1    파리      8
# 2   울브즈     10
# 3    뮌헨      2
# 4  미트윌란      6

# %%
#10
query = """
SELECT player, goals, assists, team
FROM players
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists  team
# 0    손흥민     15        9   토트넘
# 1    이강인      8        6    파리
# 2    황희찬     10        3   울브즈
# 3    김민재      2        1    뮌헨
# 4    조규성      6        2  미트윌란

# %%
#1
query = """
SELECT *
FROM players
WHERE goals>=5
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists  team
# 0    손흥민     15        9   토트넘
# 1    이강인      8        6    파리
# 2    황희찬     10        3   울브즈
# 3    조규성      6        2  미트윌란

# %%
#2
query = """
SELECT *
FROM players
WHERE assists>=3
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists team
# 0    손흥민     15        9  토트넘
# 1    이강인      8        6   파리
# 2    황희찬     10        3  울브즈

# %%
#3
query = """
SELECT player, goals
FROM players
WHERE goals>=5
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals
# 0    손흥민     15
# 1    이강인      8
# 2    황희찬     10
# 3    조규성      6

# %%
#4
query = """
SELECT *
FROM players
WHERE goals>=5 and assists>=3
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists team
# 0    손흥민     15        9  토트넘
# 1    이강인      8        6   파리
# 2    황희찬     10        3  울브즈

# %%
#5
query = """
SELECT player, goals, assists
FROM players
WHERE goals>=10 and assists>=5
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists
# 0    손흥민     15        9

# %%
#6
query = """
SELECT *
FROM players
WHERE goals>=10 OR assists>=5
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists team
# 0    손흥민     15        9  토트넘
# 1    이강인      8        6   파리
# 2    황희찬     10        3  울브즈

# %%
#7
query = """
SELECT *
FROM players
WHERE goals>=10 and team="토트넘"
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists team
# 0    손흥민     15        9  토트넘

# %%
#8
query = """
SELECT *
FROM players
WHERE assists>=5 and team="토트넘"
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists team
# 0    손흥민     15        9  토트넘

# %%
#9
query = """
SELECT player, goals, assists, team
FROM players
WHERE assists>=7 or goals>=10
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists team
# 0    손흥민     15        9  토트넘
# 1    황희찬     10        3  울브즈

# %%
#10
query = """
SELECT player, goals, assists, team
FROM players
WHERE goals>=10 and assists>=5 and team="토트넘"
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists team
# 0    손흥민     15        9  토트넘

# %%
#1
query = """
SELECT *
FROM players
ORDER BY goals
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists  team
# 0    김민재      2        1    뮌헨
# 1    조규성      6        2  미트윌란
# 2    이강인      8        6    파리
# 3    황희찬     10        3   울브즈
# 4    손흥민     15        9   토트넘

# %%
#2
query = """
SELECT player, goals
FROM players
ORDER BY goals desc
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals
# 0    손흥민     15
# 1    황희찬     10
# 2    이강인      8
# 3    조규성      6
# 4    김민재      2

# %%
#3
query = """
SELECT player, assists
FROM players
ORDER BY assists
"""

pd.read_sql_query(query, conn)
# Out:
#   player  assists
# 0    김민재        1
# 1    조규성        2
# 2    황희찬        3
# 3    이강인        6
# 4    손흥민        9

# %%
#4
query = """
SELECT player, goals
FROM players
ORDER BY goals desc
LIMIT 5
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals
# 0    손흥민     15
# 1    황희찬     10
# 2    이강인      8
# 3    조규성      6
# 4    김민재      2

# %%
#5
query = """
SELECT player, assists
FROM players
ORDER BY assists desc
LIMIT 3
"""

pd.read_sql_query(query, conn)
# Out:
#   player  assists
# 0    손흥민        9
# 1    이강인        6
# 2    황희찬        3

# %%
#6
query = """
SELECT *
FROM players
WHERE goals>=5
ORDER BY goals desc
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists  team
# 0    손흥민     15        9   토트넘
# 1    황희찬     10        3   울브즈
# 2    이강인      8        6    파리
# 3    조규성      6        2  미트윌란

# %%
#7
query = """
SELECT player, goals, assists
FROM players
WHERE team="토트넘"
ORDER BY goals desc
LIMIT 5
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists
# 0    손흥민     15        9

# %%
#8
query = """
SELECT player, goals, assists
FROM players
WHERE assists>=3 and goals>=5
ORDER BY assists desc
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists
# 0    손흥민     15        9
# 1    이강인      8        6
# 2    황희찬     10        3

# %%
#9
query = """
SELECT player, goals, assists, team
FROM players
WHERE assists>=7 or goals>=10
ORDER BY goals desc
LIMIT 5
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists team
# 0    손흥민     15        9  토트넘
# 1    황희찬     10        3  울브즈

# %%
#10
query = """
SELECT player, goals, assists
FROM players
WHERE team="토트넘" and goals>=5
ORDER BY goals desc
LIMIT 3
"""

pd.read_sql_query(query, conn)
# Out:
#   player  goals  assists
# 0    손흥민     15        9
