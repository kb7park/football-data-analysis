# %%
#변수
name="박경빈"
age=25
height=173
weight=73
dream="축구데이터전문가"
print(name)
print(age)
print(height)
print(weight)
print(dream)
# Out:
# 박경빈
# 25
# 173
# 73
# 축구데이터전문가

# %%
#리스트
my_profile=["박경빈",173,73,"축구데이터전문가"]
like_team=["맨유","첼시","아스날","토트넘"]
print(my_profile)
print(like_team)
print(len(my_profile))
print(len(like_team))
print(my_profile[0])
my_profile[0]="박송림"
print(my_profile)
like_team[0]="유벤투스"
print(like_team)
# Out:
# ['박경빈', 173, 73, '축구데이터전문가']
# ['맨유', '첼시', '아스날', '토트넘']
# 4
# 4
# 박경빈
# ['박송림', 173, 73, '축구데이터전문가']
# ['유벤투스', '첼시', '아스날', '토트넘']

# %%
#if문 for문
#1번
ages = [17, 22, 19, 25, 15]

for age in ages:
    if age>=20:
        print("성인입니다")
    else:
        print("미성년자입니다")
# Out:
# 미성년자입니다
# 성인입니다
# 미성년자입니다
# 성인입니다
# 미성년자입니다

# %%
#2번
scores = [55, 82, 91, 67, 88]

for score in scores:
    if score>=80:
        print(score)
# Out:
# 82
# 91
# 88

# %%
#3번
teams = ["맨유", "울산현대", "인테르", "FC서울"]

for team in teams:
    if team == "맨유":
        print("좋아하는 팀!")
    else:
        print(team)
# Out:
# 좋아하는팀

# %%
#4번
numbers = [1, 2, 3, 4, 5, 6, 7, 8]

for number in numbers:
    if number%2==0:
        print(number)
# Out:
# 2
# 4
# 6
# 8

# %%
#5번
goals = [3, 12, 7, 15, 20, 4]

count=0

for goal in goals:
    if goal>=10:
        count=count+1

print("10이상 개수:",count)
# Out:
# 10이상 개수: 3

# %%
#변수 리스트
#1번
name="박경빈"
age=24
print(name)
print(age)
# Out:
# 박경빈
# 24

# %%
#2번
height=173
weight=73
dream="축구 데이터 분석가"
print(height)
print(weight)
print(dream)
# Out:
# 173
# 73
# 축구 데이터 분석가

# %%
#3번
teams=["맨유","첼시","아스날","맨시티"]

print(teams)
# Out:
# ['맨유', '첼시', '아스날', '맨시티']

# %%
#4번
players=["손흥민","마커스 래시포드","킬리안 음바페","리오넬 메시"]
print(players)
print(players[0])
print(players[1])
# Out:
# ['손흥민', '마커스 래시포드', '킬리안 음바페', '리오넬 메시']
# 손흥민
# 마커스 래시포드

# %%
#5번
like_teams=["맨유","첼시","아스날","맨시티"]
like_teams[1]="리버풀"
like_teams.append("에버튼")
print(like_teams)
# Out:
# ['맨유', '리버풀', '아스날', '맨시티', '에버튼']

# %%
def say_hello():
    print("안녕하세요")
say_hello()
say_hello()
say_hello()
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %%
def introduce(name):
        print(name, "입니다")

introduce("박경빈")
introduce("박송림")
# Out:
# 박경빈 입니다
# 박송림 입니다

# %%
def add(a,b):
    print(a+b)

add(3,5)
# Out:
# 8

# %%
def add(a, b):
    return a + b
result = add(3, 5)
print(result)
# Out:
# 8

# %%
def player_name(name):
    print("선수 이름은", name, "입니다")

player_name("손흥민")
player_name("이강인")
# Out:
# 선수 이름은 손흥민 입니다
# 선수 이름은 이강인 입니다

# %%
def total_points(goals, assists):
    print(goals + assists)

total_points(15, 9)
# Out:
# 24

# %%
def total_points(goals, assists):
    return goals + assists

result = total_points(15, 9)
print(result)
# Out:
# 24

# %%
def say_hello():
    print("안녕하세요")
say_hello()
# Out:
# 안녕하세요

# %%
def introduce(name):
    print(name,"입니다")

introduce("박경빈")
# Out:
# 박경빈 입니다

# %%
def add(a,b):
    print(a+b)

add(3,4)
# Out:
# 7

# %%
def like_team(team):
    print("내가 좋아하는팀은",team,"입니다")

like_team("맨유")
# Out:
# 내가 좋아하는팀은 맨유 입니다

# %%
def total_points(goal,assists):
    print(goal+assists)

total_points(15,8)
# Out:
# 23

# %%
#1번
def say_hello():
    print("안녕하세요")

say_hello()
# Out:
# 안녕하세요

# %%
#2번
def introduce(name):
    print(name,"입니다")

introduce("박경빈")
# Out:
# 박경빈 입니다

# %%
#3번
def add(a,b):
    print(a+b)

add(3,5)
# Out:
# 8

# %%
#4번
def favorite_team(team):
    print("내가 좋아하는 팀은",team,"입니다")

favorite_team("맨유")
# Out:
# 내가 좋아하는 팀은 맨유 입니다

# %%
#5번
def total_points(goals, assists):
    print(goals+assists)

total_points(15, 9)
# Out:
# 24

# %%
#1번
def add(a,b):
    return a+b

result=add(3,5)
print(result)
# Out:
# 8

# %%
#2번
def is_adult(age):
    if age>=20:
        return "성인"
    else:
        return "미성년자"

print(is_adult(25))
print(is_adult(17))
# Out:
# 성인
# 미성년자

# %%
#3번
def get_first_team(teams):
    return teams[0]

teams=["맨유","울산현대","첼시"]
print(get_first_team(teams))
# Out:
# 맨유

# %%
#4번
def print_players(players):
    for player in players:
        print(player)

players=["손흥민","이강인","김민재"]
print_players(players)
# Out:
# 손흥민
# 이강인
# 김민재

# %%
#5번
def count_high_scores(scores):
    count = 0

    for score in scores:
        if score >= 80:
            count = count + 1

    return count

scores = [55, 82, 91, 67, 88]
print(count_high_scores(scores))
# Out:
# 3
