# %%
print("HELLO, JUPYTER!")
# Out:
# HELLO, JUPYTER!

# %%
name= "kyungbin"
age= 24
teams= ["전북", "울산", "서울"]

print(name)
print(age)
print(teams)
print(teams[0])
# Out:
# kyungbin
# 24
# ['전북', '울산', '서울']
# 전북

# %%
name="my name is kyungbin"
age= 25
like_teams=["맨체스터 유나이티드", "유벤투스", "아틀레티코 마드리드"]

print(name)
print(age)
print(like_teams)
print(like_teams[0])
print(like_teams[1])
print(like_teams[2])
like_teams.append("fc서울")
print(like_teams)
# Out:
# my name is kyungbin
# 25
# ['맨체스터 유나이티드', '유벤투스', '아틀레티코 마드리드']
# 맨체스터 유나이티드
# 유벤투스
# 아틀레티코 마드리드
# ['맨체스터 유나이티드', '유벤투스', '아틀레티코 마드리드', 'fc서울']

# %%
age=24
age=25
print(age)
# Out:
# 25

# %%
name= "kyung bin"
age= 24
dream= "축구 데이터 분석가"
print(name)
print(age)
print(dream)
# Out:
# kyung bin
# 24
# 축구 데이터 분석가

# %%
teams=["맨유", "인테르", "유벤투스", "fc서울"]
print(teams)
teams.append("아틀레티코 마드리드")
print(teams)
print(teams[4])
teams[1]="울산 현대"
print(teams)
# Out:
# ['맨유', '인테르', '유벤투스', 'fc서울']
# ['맨유', '인테르', '유벤투스', 'fc서울', '아틀레티코 마드리드']
# 아틀레티코 마드리드
# ['맨유', '울산 현대', '유벤투스', 'fc서울', '아틀레티코 마드리드']

# %%
name="박경빈"
age=25
height=173
weight=70
dream="축구 데이터 분석가"
like_teams=["맨유","유벤투스","fc서울","인테르"]
like_teams[1]="울산현대"
like_teams.append("첼시")
print(name)
print(age)
print(height)
print(weight)
print(dream)
print(like_teams)
print(like_teams[0])
print(len(like_teams))
like_players=["손흥민", "마커스 래시포드", "킬리안 음바페", "크리스티아누 호날두"]
print(like_players)
# Out:
# 박경빈
# 25
# 173
# 70
# 축구 데이터 분석가
# ['맨유', '울산현대', 'fc서울', '인테르', '첼시']
# 맨유
# 5
# ['손흥민', '마커스 래시포드', '킬리안 음바페', '크리스티아누 호날두']

# %%
#자기소개
name="박경빈"
age=25
height=173
weight=73
dream="축구 데이터 분석가"
#좋아하는팀
like_teams=["맨체스터 유나이티드", "유벤투스", "인테르", "첼시"]
like_teams.append("fc 서울")
#좋아하는선수
like_players=["손흥민", "마커스 래시포드", "킬리안 음바페", "크리스티누 호날두"]
print(name)
print(age)
print(height)
print(weight)
print(like_teams)
print(like_players)
print(len(like_teams))
print(len(like_players))
#값 변경
age=26
print(age)
like_teams[0]="아스날"
print(like_teams)
# Out:
# 박경빈
# 25
# 173
# 73
# ['맨체스터 유나이티드', '유벤투스', '인테르', '첼시', 'fc 서울']
# ['손흥민', '마커스 래시포드', '킬리안 음바페', '크리스티누 호날두']
# 5
# 4
# 26
# ['아스날', '유벤투스', '인테르', '첼시', 'fc 서울']
