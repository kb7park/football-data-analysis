# %%
age=25

if age>=20:
    print("성인입니다")
# Out:
# 성인입니다

# %%
score=75

if score>=80:
    print("합격")
else:
    print("불합격")
# Out:
# 불합격

# %%
teams=["맨유","울산현대","fc서울"]

for team in teams:
    print(team)
# Out:
# 맨유
# 울산현대
# fc서울

# %%
numbers=[1,2,3,4,5]

for number in numbers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
goals=[3,10,12,9]

for goal in goals:
    if goal>=10:
        print(goal)
# Out:
# 10
# 12

# %%
#1번
age=25

if age>=20:
    print("성인입니다")
# Out:
# 성인입니다

# %%
#2번
score=75

if score>=80:
    print("합격")
else:
    print("불합격")
# Out:
# 불합격

# %%
#3번
goals=12

if goals>=10:
    print("득점이 많네")
# Out:
# 득점이 많네

# %%
#4번
team="맨유"

if team=="맨유":
    print("내가 좋아하는 팀이다")
# Out:
# 내가 좋아하는 팀이다

# %%
#5번
teams = ["맨유", "울산현대", "FC서울", "첼시"]

for team in teams:
    print(team)
# Out:
# 맨유
# 울산현대
# FC서울
# 첼시

# %%
#6번
numbers = [1, 2, 3, 4, 5]

for number in numbers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#7번
players = ["손흥민", "이강인", "김민재"]

for player in players:
    print(player)
# Out:
# 손흥민
# 이강인
# 김민재

# %%
#8번
goals=[3,12,7,15,2]

for goal in goals:
    if goal>=10:
        print(goal)
# Out:
# 12
# 15

# %%
#9번
ages=[17, 20 ,24, 19, 30]

for age in ages:
    if age>=20:
        print("성인")
# Out:
# 성인
# 성인
# 성인

# %%
#10번
teams = ["맨유", "울산현대", "첼시", "인테르"]

for team in teams:
    if team=="첼시":
        print("찾았다")
# Out:
# 찾았다

# %%
#1번
score = 85

if score>=90:
    print("A")
elif score>=80:
    print("B")
elif score>=70:
    print("C")
else:
    print("F")
# Out:
# B

# %%
#2번

scores = [65, 82, 90, 74, 88, 59]

for score in scores:
    if score>80:
        print(score)
# Out:
# 82
# 90
# 88

# %%
#3번
ages = [17, 22, 19, 25, 30, 15]

count = 0

for age in ages:
    if age >= 20:
        count = count + 1

print("성인 수:", count)
# Out:
# 성인 수: 3

# %%
#4번
goals = [3, 12, 7, 15, 20, 4]

sum = 0

for goal in goals:
    if goal>=10:
        sum= sum+goal
        
print(sum)
# Out:
# 47

# %%
#5번
teams = ["맨유", "울산현대", "인테르", "FC서울"]

for team in teams:
    if team=="맨유":
        print("프리미어리그팀")
    elif team=="울산현대":
        print("k리그팀")
    else:
        print("그외의팀")
# Out:
# 프리미어리그팀
# k리그팀
# 그외의팀
# 그외의팀

# %%
#6번
numbers = [1, 2, 3, 4, 5, 6, 7, 8]

for number in numbers:
    if number%2==0:
        print(number)
# Out:
# 2
# 4
# 6
# 8

# %%
#7번
players = ["이강인", "손흥민", "김민재", "황희찬"]

for player in players:
    if player=="손흥민":
        print("주장후보")
    else:
        print(player)
# Out:
# 이강인
# 주장후보
# 김민재
# 황희찬

# %%
#8번
scores = [95, 72, 68, 88, 54]

for score in scores:
    if score>=90:
        print("우수")
    elif 70<=score<=89:
        print("보통")
    else:
        print("노력 필요")
# Out:
# 우수
# 보통
# 노력 필요
# 보통
# 노력 필요

# %%
#9번
goals = [11, 4, 15, 9, 10, 2, 18]

count=0

for goal in goals:
    if goal>=10:
        count=count+1
        
print("10골 이상인 선수:",count)
# Out:
# 10골 이상인 선수: 4

# %%
#10번
teams = ["FC서울", "맨유", "울산현대", "FC바르셀로나", "첼시"]

for team in teams:
    if "FC" in team:
        print(team)
# Out:
# FC서울
# FC바르셀로나
