# %%
import pandas as pd

df=pd.read_csv("player_extended.csv")
print(df[["player","goals"]])
# Out:
#   player  goals
# 0    손흥민     15
# 1    이강인      8
# 2    황희찬     10
# 3    김민재      2
# 4    조규성      6

# %%
#4/6
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]= "Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["player"],df["goals"])
plt.title("Korean Player Goals")
plt.xlabel("Player")
plt.ylabel("Goals")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("teams_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["team"],df["points"])
plt.title("팀별 누적 승점")
plt.xlabel("팀")
plt.ylabel("승점")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["player"],df["assists"])
plt.title("누적 도움 수")
plt.xlabel("선수")
plt.ylabel("도움")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["player"],df["goals"])
plt.title("선수별 득점 막대 그래프")
plt.xlabel("선수")
plt.ylabel("득점")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["player"],df["assists"])
plt.title("선수별 도움 막대그래프")
plt.xlabel("선수")
plt.ylabel("도움")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.pie(df["goals"], labels=df["player"], autopct="%1.1f%%")
plt.title("선수별 득점 비율")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.pie(df["assists"],labels=df["player"], autopct="%1.1f%%")
plt.title("선수별 도움 비율 원형그래프")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["player"],df["shots"])
plt.title("선수별 슈팅 수 막대그래프")
plt.xlabel("선수")
plt.ylabel("슈팅 수")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["player"],df["pass_accuracy"])
plt.title("선수별 패스 성공률")
plt.xlabel("선수")
plt.ylabel("패스성공률")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("teams_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["team"],df["points"])
plt.title("팀별 승점 그래프")
plt.xlabel("팀명")
plt.ylabel("누적 승점")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("teams_extended.csv")

plt.figure(figsize=(8,5))
plt.pie(df["points"],labels=df["team"], autopct="%1.1f%%")
plt.title("팀별 승점 원형그래프")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("teams_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["team"],df["possession"])
plt.title("팀별 점유율 막대그래프")
plt.xlabel("팀명")
plt.ylabel("점유율")
plt.show()

# %%
import pandas as pd

df=pd.read_csv("player_extended.csv")
print(df)
# Out:
#   player  team position  matches  minutes  goals  assists  shots  key_passes  \
# 0    손흥민   토트넘       FW       28     2350     15        9     82          47
# 1    이강인    파리       MF       24     1710      8        6     41          55
# 2    황희찬   울브즈       FW       22     1645     10        3     50          21
# 3    김민재    뮌헨       DF       26     2210      2        1     10           6
# 4    조규성  미트윌란       FW       20     1490      6        2     37          14
#
#    passes  pass_accuracy  dribbles  tackles  interceptions  yellow_cards
# 0     945           84.2        51       12              6             2
# 1    1088           88.7        43       18             11             3
# 2     612           79.8        38       16              8             4
# 3    1725           91.5         5       41             33             5
# 4     428           76.9        17        9              4             2

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

five_goals=df[df["goals"]>=5]

plt.figure(figsize=(8,5))
plt.bar(five_goals["player"],five_goals["goals"])
plt.title("득점이 5 이상인 선수")
plt.xlabel("선수")
plt.ylabel("득점")
plt.show()

# %%
#4/7
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["player"],df["goals"])
plt.title("선수별 득점 막대그래프")
plt.xlabel("선수")
plt.ylabel("득점")
plt.show()
#득점그래프에서 손흥민은 가장 많은 수치를 기록하고 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["player"],df["assists"])
plt.title("선수별 도움 막대그래프")
plt.xlabel("선수")
plt.ylabel("도움")
plt.show()
#도움수치에서도 손흥민선수가 가장 높은 수치를 기록하고 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["player"],df["shots"])
plt.title("선수별 슈팅 수 막대그래프")
plt.xlabel("선수")
plt.ylabel("슈팅")
plt.show()
#슈팅 부분에서도 손흥민 선수가 가장 많은 기록을 나타내고 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["player"],df["pass_accuracy"])
plt.title("선수별 패스성공률 막대그래프")
plt.xlabel("선수")
plt.ylabel("패스 성공률")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.pie(df["goals"], labels=df["player"], autopct= "%1.1f%%")
plt.title("선수별 득점 원형그래프")
plt.show()
#우리나라 득점 중 손흥민이 가장 높은 수치를 기록하고 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

plt.figure(figsize=(8,5))
plt.pie(df["assists"],labels=df["player"],autopct="%1.1f%%")
plt.title("선수별 도움 비율 원형그래프")
plt.show()
#우리나라 도움 수치중 손흥민이 가장 높은 수치를 기록하고 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("teams_extended.csv")

plt.figure(figsize=(8,5))
plt.pie(df["points"],labels=df["team"],autopct="%1.1f%%")
plt.title("팀별 승점 막대그래프")
plt.show()
#맨유,포항,첼시 이 세팀이 가장 많은 승점을 획득하고 있고, 서울이 0%로 가장 낮다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("teams_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["team"],df["possession"])
plt.title("팀별 점유율 막대그래프")
plt.xlabel("팀")
plt.ylabel("점유율")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("teams_extended.csv")

plt.figure(figsize=(8,5))
plt.pie(df["points"],labels=df["team"],autopct="%1.1f%%")
plt.title("팀별 승점 비율 원형그래프")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

five_goals=df[df["goals"]>=5]

plt.figure(figsize=(8,5))
plt.bar(five_goals["player"],five_goals["goals"])
plt.title("득점 5이상인 선수의 득점 막대그래프")
plt.xlabel("선수")
plt.ylabel("득점")
plt.show()

# %%
#4/8
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

five_goals=df[df["goals"]>=5]

plt.figure(figsize=(8,5))
plt.bar(five_goals["player"],five_goals["goals"])
plt.title("득점 5 이상 선수 득점")
plt.xlabel("선수")
plt.ylabel("득점")
plt.show()
#아래 그래프는 득점 5이상인 선수들을 막대그래프로 보여준 것으로 15골로 손흥민 선수가 가장 높은 수치를 기록하고 있고 조규성 선수는 6골로 준수한
#기록을 가지고 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

chancemaker=df[df["key_passes"]>=20]
plt.figure(figsize=(8,5))
plt.pie(chancemaker["key_passes"],labels=chancemaker["player"],autopct="%1.1f%%")
plt.title("찬스메이커")
plt.show()
#키패스 20개 이상 기록한 선수들중 가장 많은 수치를 기록한 선수는 이강인이다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

high_assists=df[df["assists"]>=3]

plt.figure(figsize=(8,5))
plt.pie(high_assists["assists"],labels=high_assists["player"],autopct="%1.1f%%")
plt.title("도움 3 이상인 선수들의 원형그래프")
plt.show()
#도움 3 이상인 선수들 중에서 손흥민 선수가 가장 많은 도움비율을 기록하고 있다.

# %%
#4/9
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

#득점 수
plt.figure(figsize=(8,5))
plt.bar(df["player"],df["goals"])
plt.title("득점 비교 막대그래프")
plt.xlabel("선수")
plt.ylabel("득점")
plt.show()
#득점 비율
plt.figure(figsize=(8,5))
plt.pie(df["goals"],labels=df["player"],autopct="%1.1f%%")
plt.title("득점 비율 원형그래프")
plt.show()
#우리나라 선수들의 득점을 그래프로 나타낸것으로 우리나라 선수들중 가장 많은 득점을 기록한 선수는 손흥민 선수이다. 그다음으로는 황희찬 선수가
#가장 높은 수치를 기록하고 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")
#키패스 수
plt.figure(figsize=(8,5))
plt.bar(df["player"],df["key_passes"])
plt.title("우리나라 선수들의 키패스 수")
plt.xlabel("선수")
plt.ylabel("키패스 수")
plt.show()
#패스 성공률
plt.figure(figsize=(8,5))
plt.bar(df["player"],df["pass_accuracy"])
plt.title("우리나라 선수들의 패스 성공률")
plt.xlabel("선수")
plt.ylabel("패스 성공률")
plt.show()
#우리나라 선수들의 키패스 수 패스 성공률의 막대그래프로 우리나라 선수들중 키패스 수도 높으면서 패스 성공률이 높은 선수는 이강인 선수이다. 그래프를 
#보면 이강인 선수가 키패스 수가높고 패스 성공률도 안정적으로 나타나 다른 선수들보다 공격 전개와 찬스 창출에 강점을 보인다고 해석된다.
#따라서 이강인 선수는 플레이메이커 역할에 적합한 선수라고 볼 수 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("teams_extended.csv")

plt.figure(figsize=(8,5))
plt.bar(df["team"],df["points"])
plt.title("팀별 누적 승점")
plt.xlabel("팀")
plt.ylabel("승점")
plt.show()
#위 그래프는 팀별 누적 승점을 막대그래프로 나타낸 것이다.
#그래프를 보면 맨유, 첼시, 포항이 승점 3점으로 가장 높은 승점을 기록하고 있다.
#그다음 울산은 승점 1점, 서울은 승점 0점을 기록하고 있다.
#현재 최대승점이 3점인 것으로 보아 시즌 초반데이터로 해석 할 수 있을거 같다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"]="Malgun Gothic"
plt.rcParams["axes.unicode_minus"]=False

df=pd.read_csv("player_extended.csv")

#태클횟수
plt.figure(figsize=(8,5))
plt.bar(df["player"],df["tackles"])
plt.title("우리나라 선수들의 태클 횟수")
plt.xlabel("선수")
plt.ylabel("태클 횟수")
plt.show()
#인터셉트 횟수
plt.figure(figsize=(8,5))
plt.bar(df["player"],df["interceptions"])
plt.title("우리나라 선수들의 인터셉트 횟수")
plt.xlabel("선수")
plt.ylabel("인터셉트 횟수")
plt.show()
#위 그래프는 우리나라 선수들의 태클 횟수, 인터셉트 횟수를 나타낸것이다.
#김민재 선수는 다른 선수들에 비해 태클과 인터셉트 수치에서 높은 값을 기록하고 있다.
#김민재 선수는 수비 상황에서 공을 차단하고 상대 공격을 끊어내는 능력이 뛰어난 선수라고 해석할 수 있다.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["font.family"] = "Malgun Gothic"
plt.rcParams["axes.unicode_minus"] = False

df = pd.read_csv("player_extended.csv")

# 슈팅 대비 골 비율 계산
df["goal_per_shot"] = (df["goals"] / df["shots"]) * 100

print(df[["player", "goals", "shots", "goal_per_shot"]])

plt.figure(figsize=(8,5))
plt.bar(df["player"], df["goal_per_shot"])
plt.title("우리나라 선수들의 슈팅 대비 골 비율")
plt.xlabel("선수")
plt.ylabel("골 비율(%)")
plt.xticks(rotation=45)
plt.show()
#위 그래프는 우리나라 선수들의 슈팅 대비 골 비율을 기록한 것이다.
#슈팅 대비 골 비율이 높을수록 적은 슈팅으로도 득점으로 연결하는 효율이 높다고 볼 수 있다.
#손흥민 선수는 가장 많은 득점과 가장 많은 슈팅 수를 기록하며 높은 공격 기여도를 보였다.
#황희찬 선수와 김민재 선수는 슈팅 대비 골 비율이 가장 높게 나타나 적은 슈팅에 비해 득점 효율이 좋은 선수라고 해석할 수 있다.
# Out:
#   player  goals  shots  goal_per_shot
# 0    손흥민     15     82      18.292683
# 1    이강인      8     41      19.512195
# 2    황희찬     10     50      20.000000
# 3    김민재      2     10      20.000000
# 4    조규성      6     37      16.216216

# %%
#전체 데이터를 종합해보면 손흥민 선수는 득점 능력이 뛰어난 공격수로 해석할 수 있다.
#이강인 선수는 키패스와 패스 성공률에서 강점을 보여 공격 전개의 중심 역할에 적합하다고 볼 수 있다.
#김민재 선수는 태클과 인터셉트 수치가 높아 수비에서 핵심적인 역할을 하는 선수라고 해석할 수 있다.
